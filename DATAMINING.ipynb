# %%
import requests
jsons=[]
r = requests.get('https://api.github.com/search/repositories?q=machine+learning+language:java&sort=stars&order=desc')
jsons.append(r)
r = requests.get('https://api.github.com/search/repositories?q=neural+language:java&sort=stars&order=desc')
jsons.append(r)
r = requests.get('https://api.github.com/search/repositories?q=language:java&sort=stars&order=desc')
jsons.append(r)
r = requests.get('https://api.github.com/search/repositories?q=db+language:java&sort=stars&order=desc')
jsons.append(r)
r = requests.get('https://api.github.com/search/repositories?q=engine+language:java&sort=stars&order=desc')
jsons.append(r)
r = requests.get('https://api.github.com/search/repositories?q=language:shell&sort=stars&order=desc')
jsons.append(r)
r = requests.get('https://api.github.com/search/repositories?q=android+language:java&sort=stars&order=desc')
jsons.append(r)
r = requests.get('https://api.github.com/search/repositories?q=video+language:javascript&sort=stars&order=desc')
jsons.append(r)
r = requests.get('https://api.github.com/search/repositories?q=ios+language:objective-c&sort=stars&order=desc')
jsons.append(r)
r = requests.get('https://api.github.com/search/repositories?q=vr+language:c++&sort=stars&order=desc')
jsons.append(r)

#input_dict = json.loads(r.json())
# Filter python objects with list comprehensions

# %%
import unicodedata
final_url_lists=[]
for x in range(len(jsons)):
    #url_list=[unicodedata.normalize('NFKD',jsons[x].json().get('items')[i].get('url')).encode('ascii','ignore') for i in range(len(r.json().get('items')))]
    url_list=[jsons[x].json().get('items')[i].get('url') for i in range(len(r.json().get('items')))]
    final_url_lists.append(url_list)
#owner_list=[r.json().get('items')[i].get('owner') for i in range(len(r.json().get('items')))]
name_list=[r.json().get('items')[i].get('name') for i in range(len(r.json().get('items')))]
# Transform python object back into json

# Show json
print len(final_url_lists)
# Out:
# 10

# %%
final_list=[]
for i in range(len(final_url_lists)):
    temp_list=final_url_lists[i]
    for j in range(len(temp_list)):
        final_list.append(temp_list[j].encode("UTF-8"))
final_list
# Out:
# ['https://api.github.com/repos/haifengl/smile',
#  'https://api.github.com/repos/Tencent/angel',
#  'https://api.github.com/repos/h2oai/h2o-3',
#  'https://api.github.com/repos/h2oai/h2o-2',
#  'https://api.github.com/repos/ICT-BDA/EasyML',
#  'https://api.github.com/repos/OryxProject/oryx',
#  'https://api.github.com/repos/SeldonIO/seldon-server',
#  'https://api.github.com/repos/datumbox/datumbox-framework',
#  'https://api.github.com/repos/MindorksOpenSource/AndroidTensorFlowMachineLearningExample',
#  'https://api.github.com/repos/mimno/Mallet',
#  'https://api.github.com/repos/pmerienne/trident-ml',
#  'https://api.github.com/repos/etsy/Conjecture',
#  'https://api.github.com/repos/EdwardRaff/JSAT',
#  'https://api.github.com/repos/kermitt2/grobid',
#  'https://api.github.com/repos/hanuor/onyx',
#  'https://api.github.com/repos/o19s/elasticsearch-learning-to-rank',
#  'https://api.github.com/repos/antlr/codebuff',
#  'https://api.github.com/repos/imageprocessor/cv4j',
# ...

# %%
import csv



with open("urls.csv", 'wb') as myfile:
    wr = csv.writer(myfile, quoting=csv.QUOTE_ALL)
    wr.writerow(final_list)

# %%
final_list
# Out:
# [u'https://api.github.com/repos/haifengl/smile',
#  u'https://api.github.com/repos/Tencent/angel',
#  u'https://api.github.com/repos/h2oai/h2o-3',
#  u'https://api.github.com/repos/h2oai/h2o-2',
#  u'https://api.github.com/repos/ICT-BDA/EasyML',
#  u'https://api.github.com/repos/OryxProject/oryx',
#  u'https://api.github.com/repos/SeldonIO/seldon-server',
#  u'https://api.github.com/repos/datumbox/datumbox-framework',
#  u'https://api.github.com/repos/MindorksOpenSource/AndroidTensorFlowMachineLearningExample',
#  u'https://api.github.com/repos/mimno/Mallet',
#  u'https://api.github.com/repos/pmerienne/trident-ml',
#  u'https://api.github.com/repos/etsy/Conjecture',
#  u'https://api.github.com/repos/EdwardRaff/JSAT',
#  u'https://api.github.com/repos/kermitt2/grobid',
#  u'https://api.github.com/repos/hanuor/onyx',
#  u'https://api.github.com/repos/o19s/elasticsearch-learning-to-rank',
#  u'https://api.github.com/repos/antlr/codebuff',
# ...

# %%
with open("urls.csv", 'wb') as myfile:
    wr = csv.writer(myfile)
    wr.writerow(final_list)
final_list
# Out:
# ['https://api.github.com/repos/haifengl/smile',
#  'https://api.github.com/repos/Tencent/angel',
#  'https://api.github.com/repos/h2oai/h2o-3',
#  'https://api.github.com/repos/h2oai/h2o-2',
#  'https://api.github.com/repos/ICT-BDA/EasyML',
#  'https://api.github.com/repos/OryxProject/oryx',
#  'https://api.github.com/repos/SeldonIO/seldon-server',
#  'https://api.github.com/repos/datumbox/datumbox-framework',
#  'https://api.github.com/repos/MindorksOpenSource/AndroidTensorFlowMachineLearningExample',
#  'https://api.github.com/repos/mimno/Mallet',
#  'https://api.github.com/repos/pmerienne/trident-ml',
#  'https://api.github.com/repos/etsy/Conjecture',
#  'https://api.github.com/repos/EdwardRaff/JSAT',
#  'https://api.github.com/repos/kermitt2/grobid',
#  'https://api.github.com/repos/hanuor/onyx',
#  'https://api.github.com/repos/o19s/elasticsearch-learning-to-rank',
#  'https://api.github.com/repos/antlr/codebuff',
#  'https://api.github.com/repos/imageprocessor/cv4j',
# ...

# %%
with open('urls.csv', 'rb') as f:
    reader = csv.reader(f)
    to_download = list(reader)
to_download=to_download[0]

# %%
to_download
# Out:
# ['https://api.github.com/repos/haifengl/smile',
#  'https://api.github.com/repos/Tencent/angel',
#  'https://api.github.com/repos/h2oai/h2o-3',
#  'https://api.github.com/repos/h2oai/h2o-2',
#  'https://api.github.com/repos/ICT-BDA/EasyML',
#  'https://api.github.com/repos/OryxProject/oryx',
#  'https://api.github.com/repos/SeldonIO/seldon-server',
#  'https://api.github.com/repos/datumbox/datumbox-framework',
#  'https://api.github.com/repos/MindorksOpenSource/AndroidTensorFlowMachineLearningExample',
#  'https://api.github.com/repos/mimno/Mallet',
#  'https://api.github.com/repos/pmerienne/trident-ml',
#  'https://api.github.com/repos/etsy/Conjecture',
#  'https://api.github.com/repos/EdwardRaff/JSAT',
#  'https://api.github.com/repos/kermitt2/grobid',
#  'https://api.github.com/repos/hanuor/onyx',
#  'https://api.github.com/repos/o19s/elasticsearch-learning-to-rank',
#  'https://api.github.com/repos/antlr/codebuff',
#  'https://api.github.com/repos/imageprocessor/cv4j',
# ...

# %%
with open('URLforPRATIK.csv', 'rb') as f:
    reader = csv.reader(f)
    u = list(reader)
final_list=[]
for i in range(125):
    final_list.append(u[i][0])
with open("urls1.csv", 'wb') as myfile:
    wr = csv.writer(myfile)
    wr.writerow(final_list)
    
with open('NAMES.csv', 'rb') as f:
    reader = csv.reader(f)
    w = list(reader)
wfinal_list=[]
for i in range(125):
    wfinal_list.append(w[i][0])
with open("names1.csv", 'wb') as myfile:
    wr = csv.writer(myfile)
    wr.writerow(wfinal_list)

# %%
final_list=[]
for i in range(125,250):
    final_list.append(u[i][0])
with open("urls2.csv", 'wb') as myfile:
    wr = csv.writer(myfile)
    wr.writerow(final_list)
    

wfinal_list=[]
for i in range(125,250):
    wfinal_list.append(w[i][0])
with open("names2.csv", 'wb') as myfile:
    wr = csv.writer(myfile)
    wr.writerow(wfinal_list)

# %%
final_list=[]
for i in range(250,375):
    final_list.append(u[i][0])
with open("urls3.csv", 'wb') as myfile:
    wr = csv.writer(myfile)
    wr.writerow(final_list)

wfinal_list=[]
for i in range(250,375):
    wfinal_list.append(w[i][0])
with open("names3.csv", 'wb') as myfile:
    wr = csv.writer(myfile)
    wr.writerow(wfinal_list)

# %%
final_list=[]
for i in range(375,500):
    final_list.append(u[i][0])
with open("urls4.csv", 'wb') as myfile:
    wr = csv.writer(myfile)
    wr.writerow(final_list)
    
wfinal_list=[]
for i in range(375,500):
    wfinal_list.append(w[i][0])
with open("names4.csv", 'wb') as myfile:
    wr = csv.writer(myfile)
    wr.writerow(wfinal_list)
